# %%
import pandas as pd


df = pd.read_csv('ready_data_030.csv', low_memory=False)
df
# Out:
#         country_or_area  ISO  year   transaction_type  \
# 0               Austria  AUT  1996            exports
# 1               Austria  AUT  1995            exports
# 2               Belgium  BEL  2014            exports
# 3               Belgium  BEL  2013            exports
# 4               Belgium  BEL  2012            exports
# ...                 ...  ...   ...                ...
# 1032027        Viet Nam  VNM  2012  total wproduction
# 1032028        Viet Nam  VNM  2011  total wproduction
# 1032029        Viet Nam  VNM  2010  total wproduction
# 1032030        Viet Nam  VNM  2009  total wproduction
# 1032031        Viet Nam  VNM  2008  total wproduction
#
#                             unit  quantity                  category  CL4  \
# 0         Metric tons,  thousand       5.0  additives_and_oxygenates  NaN
# 1         Metric tons,  thousand      17.0  additives_and_oxygenates  NaN
# 2         Metric tons,  thousand       0.0  additives_and_oxygenates  NaN
# 3         Metric tons,  thousand       0.0  additives_and_oxygenates  NaN
# 4         Metric tons,  thousand      35.0  additives_and_oxygenates  NaN
# ...                          ...       ...                       ...  ...
# 1032027  Kilowatt-hours, million      92.0          wind_electricity  NaN
# 1032028  Kilowatt-hours, million      87.0          wind_electricity  NaN
# 1032029  Kilowatt-hours, million      50.0          wind_electricity  NaN
# 1032030  Kilowatt-hours, million      10.0          wind_electricity  NaN
# 1032031  Kilowatt-hours, million       1.0          wind_electricity  NaN
#
#          CL3      CL2                commodity_transaction  \
# 0        NaN  exports   Additives and Oxygenates - Exports
# 1        NaN  exports   Additives and Oxygenates - Exports
# 2        NaN  exports   Additives and Oxygenates - Exports
# 3        NaN  exports   Additives and Oxygenates - Exports
# 4        NaN  exports   Additives and Oxygenates - Exports
# ...      ...      ...                                  ...
# 1032027  NaN      NaN  Electricity - total wind production
# 1032028  NaN      NaN  Electricity - total wind production
# 1032029  NaN      NaN  Electricity - total wind production
# 1032030  NaN      NaN  Electricity - total wind production
# 1032031  NaN      NaN  Electricity - total wind production
#
#                         commodity   L1                        L2 L3 L4  \
# 0        additives and oxygenates  oil  additives_and_oxygenates  0  0
# 1        additives and oxygenates  oil  additives_and_oxygenates  0  0
# 2        additives and oxygenates  oil  additives_and_oxygenates  0  0
# 3        additives and oxygenates  oil  additives_and_oxygenates  0  0
# 4        additives and oxygenates  oil  additives_and_oxygenates  0  0
# ...                           ...  ...                       ... .. ..
# 1032027               electricity    0                         0  0  0
# 1032028               electricity    0                         0  0  0
# 1032029               electricity    0                         0  0  0
# 1032030               electricity    0                         0  0  0
# 1032031               electricity    0                         0  0  0
#
#                           new_unit  new_quantity
# 0           Metric tons,  thousand           5.0
# 1           Metric tons,  thousand          17.0
# 2           Metric tons,  thousand           0.0
# 3           Metric tons,  thousand           0.0
# 4           Metric tons,  thousand          35.0
# ...                            ...           ...
# 1032027  Kilowatt-hours,  thousand       92000.0
# 1032028  Kilowatt-hours,  thousand       87000.0
# 1032029  Kilowatt-hours,  thousand       50000.0
# 1032030  Kilowatt-hours,  thousand       10000.0
# 1032031  Kilowatt-hours,  thousand        1000.0
#
# [1032032 rows x 18 columns]

# %% [markdown]
# ### wybrane kolumny

# %%
df = df[['country_or_area', 'ISO', 'year', 'new_unit', 'new_quantity','commodity_transaction', 'category']]
df
# Out:
#         country_or_area  ISO  year                   new_unit  new_quantity  \
# 0               Austria  AUT  1996     Metric tons,  thousand           5.0
# 1               Austria  AUT  1995     Metric tons,  thousand          17.0
# 2               Belgium  BEL  2014     Metric tons,  thousand           0.0
# 3               Belgium  BEL  2013     Metric tons,  thousand           0.0
# 4               Belgium  BEL  2012     Metric tons,  thousand          35.0
# ...                 ...  ...   ...                        ...           ...
# 1032027        Viet Nam  VNM  2012  Kilowatt-hours,  thousand       92000.0
# 1032028        Viet Nam  VNM  2011  Kilowatt-hours,  thousand       87000.0
# 1032029        Viet Nam  VNM  2010  Kilowatt-hours,  thousand       50000.0
# 1032030        Viet Nam  VNM  2009  Kilowatt-hours,  thousand       10000.0
# 1032031        Viet Nam  VNM  2008  Kilowatt-hours,  thousand        1000.0
#
#                        commodity_transaction                  category
# 0         Additives and Oxygenates - Exports  additives_and_oxygenates
# 1         Additives and Oxygenates - Exports  additives_and_oxygenates
# 2         Additives and Oxygenates - Exports  additives_and_oxygenates
# 3         Additives and Oxygenates - Exports  additives_and_oxygenates
# 4         Additives and Oxygenates - Exports  additives_and_oxygenates
# ...                                      ...                       ...
# 1032027  Electricity - total wind production          wind_electricity
# 1032028  Electricity - total wind production          wind_electricity
# 1032029  Electricity - total wind production          wind_electricity
# 1032030  Electricity - total wind production          wind_electricity
# 1032031  Electricity - total wind production          wind_electricity
#
# [1032032 rows x 7 columns]

# %% [markdown]
# ### wybrane kategorie

# %%
#List of columns selected for analysis
data_list = ['Electricity - Gross production',
             #'Electricity - total production, main activity', 
             #'Electricity - total production, autoproducer',
             'Electricity - total thermal production', 
             'Electricity - total nuclear production',
             'Electricity - total geothermal production', 
             'Electricity - total hydro production',
             'Electricity - total solar production',
             'Electricity - total tide, wave production',
             'Electricity - total wind production',
             'From chemical heat – Autoproducer',
             'From chemical heat – Main activity',
             'From other sources – Autoproducer',
             'From other sources – Main activity']
                 
df = df[df['commodity_transaction'].isin(data_list)]
df.head()
# Out:
#        country_or_area  ISO  year                   new_unit  new_quantity  \
# 423933       Australia  AUS  2014  Kilowatt-hours,  thousand        1000.0
# 423934       Australia  AUS  2013  Kilowatt-hours,  thousand        1000.0
# 423935       Australia  AUS  2012  Kilowatt-hours,  thousand        1000.0
# 423936       Australia  AUS  2011  Kilowatt-hours,  thousand        1000.0
# 423937       Australia  AUS  2010  Kilowatt-hours,  thousand        1000.0
#
#                             commodity_transaction    category
# 423933  Electricity - total geothermal production  geothermal
# 423934  Electricity - total geothermal production  geothermal
# 423935  Electricity - total geothermal production  geothermal
# 423936  Electricity - total geothermal production  geothermal
# 423937  Electricity - total geothermal production  geothermal

# %%
x = df[df['commodity_transaction'] == "Electricity - total hydro production"]['new_quantity'].sum()
y = df[df['commodity_transaction'] == 'Electricity - total tide, wave production']['new_quantity'].sum()

a = x+y
print('x: ', x, ' +  y: ',y, ' = ', a )
# Out:
# x:  63726372610.24  +  y:  11694000.0  =  63738066610.24

# %% [markdown]
# ### Adding "Electricity - total hydro production" to 'Electricity - total tide, wave production'

# %%
dict_com_tr = {"Electricity - total hydro production":'Electricity - total tide, wave and hydro production',
         'Electricity - total tide, wave production': 'Electricity - total tide, wave and hydro production' }
dict_category = {'tide_wave_and_ocean_electricity': 'hydro_electricity',
                    'hydro':'hydro_electricity'}
df['commodity_transaction'] = df['commodity_transaction'].replace(dict_com_tr)
df['category'] = df['category'].replace(dict_category)
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2168\703847972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['commodity_transaction'] = df['commodity_transaction'].replace(dict_com_tr)
# C:\Users\user\AppData\Local\Temp\ipykernel_2168\703847972.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['category'] = df['category'].replace(dict_category)
#        country_or_area  ISO  year                   new_unit  new_quantity  \
# 423933       Australia  AUS  2014  Kilowatt-hours,  thousand        1000.0
# 423934       Australia  AUS  2013  Kilowatt-hours,  thousand        1000.0
# 423935       Australia  AUS  2012  Kilowatt-hours,  thousand        1000.0
# 423936       Australia  AUS  2011  Kilowatt-hours,  thousand        1000.0
# 423937       Australia  AUS  2010  Kilowatt-hours,  thousand        1000.0
#
#                             commodity_transaction    category
# 423933  Electricity - total geothermal production  geothermal
# 423934  Electricity - total geothermal production  geothermal
# 423935  Electricity - total geothermal production  geothermal
# 423936  Electricity - total geothermal production  geothermal
# 423937  Electricity - total geothermal production  geothermal

# %%
df = df.groupby(['country_or_area','ISO','commodity_transaction','year','category','new_unit']).agg({'new_quantity':'sum'}).reset_index()
df.head(50)
# Out:
#    country_or_area  ISO                              commodity_transaction  \
# 0      Afghanistan  AFG                     Electricity - Gross production
# 1      Afghanistan  AFG                     Electricity - Gross production
# 2      Afghanistan  AFG                     Electricity - Gross production
# 3      Afghanistan  AFG                     Electricity - Gross production
# 4      Afghanistan  AFG                     Electricity - Gross production
# 5      Afghanistan  AFG                     Electricity - Gross production
# 6      Afghanistan  AFG                     Electricity - Gross production
# 7      Afghanistan  AFG                     Electricity - Gross production
# 8      Afghanistan  AFG                     Electricity - Gross production
# 9      Afghanistan  AFG                     Electricity - Gross production
# 10     Afghanistan  AFG                     Electricity - Gross production
# 11     Afghanistan  AFG                     Electricity - Gross production
# 12     Afghanistan  AFG                     Electricity - Gross production
# 13     Afghanistan  AFG                     Electricity - Gross production
# 14     Afghanistan  AFG                     Electricity - Gross production
# 15     Afghanistan  AFG                     Electricity - Gross production
# 16     Afghanistan  AFG                     Electricity - Gross production
# 17     Afghanistan  AFG                     Electricity - Gross production
# 18     Afghanistan  AFG                     Electricity - Gross production
# 19     Afghanistan  AFG                     Electricity - Gross production
# 20     Afghanistan  AFG                     Electricity - Gross production
# 21     Afghanistan  AFG             Electricity - total thermal production
# 22     Afghanistan  AFG             Electricity - total thermal production
# 23     Afghanistan  AFG             Electricity - total thermal production
# 24     Afghanistan  AFG             Electricity - total thermal production
# 25     Afghanistan  AFG             Electricity - total thermal production
# 26     Afghanistan  AFG             Electricity - total thermal production
# 27     Afghanistan  AFG             Electricity - total thermal production
# 28     Afghanistan  AFG             Electricity - total thermal production
# 29     Afghanistan  AFG             Electricity - total thermal production
# 30     Afghanistan  AFG             Electricity - total thermal production
# 31     Afghanistan  AFG             Electricity - total thermal production
# 32     Afghanistan  AFG             Electricity - total thermal production
# 33     Afghanistan  AFG             Electricity - total thermal production
# 34     Afghanistan  AFG             Electricity - total thermal production
# 35     Afghanistan  AFG             Electricity - total thermal production
# 36     Afghanistan  AFG             Electricity - total thermal production
# 37     Afghanistan  AFG             Electricity - total thermal production
# 38     Afghanistan  AFG             Electricity - total thermal production
# 39     Afghanistan  AFG             Electricity - total thermal production
# 40     Afghanistan  AFG             Electricity - total thermal production
# 41     Afghanistan  AFG             Electricity - total thermal production
# 42     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 43     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 44     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 45     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 46     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 47     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 48     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
# 49     Afghanistan  AFG  Electricity - total tide, wave and hydro produ...
#
#     year             category                   new_unit  new_quantity
# 0   1994    total_electricity  Kilowatt-hours,  thousand      687000.0
# 1   1995    total_electricity  Kilowatt-hours,  thousand      675000.0
# 2   1996    total_electricity  Kilowatt-hours,  thousand      675000.0
# 3   1997    total_electricity  Kilowatt-hours,  thousand      670000.0
# 4   1998    total_electricity  Kilowatt-hours,  thousand      665000.0
# 5   1999    total_electricity  Kilowatt-hours,  thousand      685000.0
# 6   2000    total_electricity  Kilowatt-hours,  thousand      687700.0
# 7   2001    total_electricity  Kilowatt-hours,  thousand      691100.0
# 8   2002    total_electricity  Kilowatt-hours,  thousand      722200.0
# 9   2003    total_electricity  Kilowatt-hours,  thousand      976000.0
# 10  2004    total_electricity  Kilowatt-hours,  thousand      780000.0
# 11  2005    total_electricity  Kilowatt-hours,  thousand      906000.0
# 12  2006    total_electricity  Kilowatt-hours,  thousand      913000.0
# 13  2007    total_electricity  Kilowatt-hours,  thousand      950000.0
# 14  2008    total_electricity  Kilowatt-hours,  thousand      788000.0
# 15  2009    total_electricity  Kilowatt-hours,  thousand      889000.0
# 16  2010    total_electricity  Kilowatt-hours,  thousand      892000.0
# 17  2011    total_electricity  Kilowatt-hours,  thousand     1005000.0
# 18  2012    total_electricity  Kilowatt-hours,  thousand     1022000.0
# 19  2013    total_electricity  Kilowatt-hours,  thousand     1022300.0
# 20  2014    total_electricity  Kilowatt-hours,  thousand     1049300.0
# 21  1994  thermal_electricity  Kilowatt-hours,  thousand      215000.0
# 22  1995  thermal_electricity  Kilowatt-hours,  thousand      209000.0
# 23  1996  thermal_electricity  Kilowatt-hours,  thousand      200000.0
# 24  1997  thermal_electricity  Kilowatt-hours,  thousand      185000.0
# 25  1998  thermal_electricity  Kilowatt-hours,  thousand      170000.0
# 26  1999  thermal_electricity  Kilowatt-hours,  thousand      180000.0
# 27  2000  thermal_electricity  Kilowatt-hours,  thousand      172000.0
# 28  2001  thermal_electricity  Kilowatt-hours,  thousand      187900.0
# 29  2002  thermal_electricity  Kilowatt-hours,  thousand      151200.0
# 30  2003  thermal_electricity  Kilowatt-hours,  thousand      329000.0
# 31  2004  thermal_electricity  Kilowatt-hours,  thousand      215000.0
# 32  2005  thermal_electricity  Kilowatt-hours,  thousand      235000.0
# 33  2006  thermal_electricity  Kilowatt-hours,  thousand      267000.0
# 34  2007  thermal_electricity  Kilowatt-hours,  thousand      266000.0
# 35  2008  thermal_electricity  Kilowatt-hours,  thousand      247000.0
# 36  2009  thermal_electricity  Kilowatt-hours,  thousand      114000.0
# 37  2010  thermal_electricity  Kilowatt-hours,  thousand      125000.0
# 38  2011  thermal_electricity  Kilowatt-hours,  thousand      176000.0
# 39  2012  thermal_electricity  Kilowatt-hours,  thousand      144000.0
# 40  2013  thermal_electricity  Kilowatt-hours,  thousand      218400.0
# 41  2014  thermal_electricity  Kilowatt-hours,  thousand      154000.0
# 42  1994    hydro_electricity  Kilowatt-hours,  thousand      472000.0
# 43  1995    hydro_electricity  Kilowatt-hours,  thousand      466000.0
# 44  1996    hydro_electricity  Kilowatt-hours,  thousand      475000.0
# 45  1997    hydro_electricity  Kilowatt-hours,  thousand      485000.0
# 46  1998    hydro_electricity  Kilowatt-hours,  thousand      495000.0
# 47  1999    hydro_electricity  Kilowatt-hours,  thousand      505000.0
# 48  2000    hydro_electricity  Kilowatt-hours,  thousand      515700.0
# 49  2001    hydro_electricity  Kilowatt-hours,  thousand      503200.0

# %% [markdown]
# ### to check

# %%
b = df[df['commodity_transaction'] == 'Electricity - total tide, wave and hydro production']['new_quantity'].sum()
print("b: ", b)
# Out:
# b:  63738066610.24

# %%
a-b
# Out:
# 0.0

# %%
df.commodity_transaction.value_counts()
# Out:
# Electricity - Gross production                         4695
# Electricity - total thermal production                 4665
# Electricity - total tide, wave and hydro production    3194
# Electricity - total wind production                    1297
# Electricity - total solar production                    907
# Electricity - total nuclear production                  647
# Electricity - total geothermal production               427
# From other sources – Autoproducer                       282
# From other sources – Main activity                      210
# From chemical heat – Autoproducer                       107
# From chemical heat – Main activity                       19
# Name: commodity_transaction, dtype: int64

# %%
df.category.value_counts()
# Out:
# total_electricity      5121
# thermal_electricity    4665
# hydro_electricity      3194
# wind_electricity       1297
# solar_electricity       907
# nuclear_electricity     647
# geothermal              427
# heat                    192
# Name: category, dtype: int64

# %% [markdown]
# ## file creation

# %%
df.to_csv('final_version.csv', index= False)
df
# Out:
#       country_or_area  ISO                              commodity_transaction  \
# 0         Afghanistan  AFG                     Electricity - Gross production
# 1         Afghanistan  AFG                     Electricity - Gross production
# 2         Afghanistan  AFG                     Electricity - Gross production
# 3         Afghanistan  AFG                     Electricity - Gross production
# 4         Afghanistan  AFG                     Electricity - Gross production
# ...               ...  ...                                                ...
# 16445        Zimbabwe  ZWE  Electricity - total tide, wave and hydro produ...
# 16446        Zimbabwe  ZWE  Electricity - total tide, wave and hydro produ...
# 16447        Zimbabwe  ZWE  Electricity - total tide, wave and hydro produ...
# 16448        Zimbabwe  ZWE  Electricity - total tide, wave and hydro produ...
# 16449        Zimbabwe  ZWE  Electricity - total tide, wave and hydro produ...
#
#        year           category                   new_unit  new_quantity
# 0      1994  total_electricity  Kilowatt-hours,  thousand      687000.0
# 1      1995  total_electricity  Kilowatt-hours,  thousand      675000.0
# 2      1996  total_electricity  Kilowatt-hours,  thousand      675000.0
# 3      1997  total_electricity  Kilowatt-hours,  thousand      670000.0
# 4      1998  total_electricity  Kilowatt-hours,  thousand      665000.0
# ...     ...                ...                        ...           ...
# 16445  2010  hydro_electricity  Kilowatt-hours,  thousand     5762800.0
# 16446  2011  hydro_electricity  Kilowatt-hours,  thousand     5201800.0
# 16447  2012  hydro_electricity  Kilowatt-hours,  thousand     5387300.0
# 16448  2013  hydro_electricity  Kilowatt-hours,  thousand     4981800.0
# 16449  2014  hydro_electricity  Kilowatt-hours,  thousand     5431000.0
#
# [16450 rows x 7 columns]
